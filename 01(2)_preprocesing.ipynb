# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("data.csv")

# %%
df = df.drop(columns=['transaction_id', 'user_id'])

# %%
df['transaction_time'] = pd.to_datetime(df['transaction_time'])

df['hour'] = df['transaction_time'].dt.hour
df['day'] = df['transaction_time'].dt.day
df['day_of_week'] = df['transaction_time'].dt.dayofweek

df = df.drop(columns=['transaction_time'])

# %%
X = df.drop('is_fraud', axis=1)
y = df['is_fraud']

# %%
X = pd.get_dummies(
    X,
    columns=['country', 'bin_country', 'channel', 'merchant_category'],
    drop_first=True
)

# %%
from sklearn.preprocessing import StandardScaler

num_cols = [
    'account_age_days',
    'total_transactions_user',
    'avg_amount_user',
    'amount',
    'shipping_distance_km'
]

scaler = StandardScaler()
X[num_cols] = scaler.fit_transform(X[num_cols])

# %%
print(X.shape)
print(X.head())
print(y.value_counts(normalize=True))
# Out:
# (299695, 35)
#    account_age_days  total_transactions_user  avg_amount_user    amount  \
# 0         -1.584794                 -0.61464        -0.001063 -0.301100
# 1         -1.584794                 -0.61464        -0.001063 -0.225674
# 2         -1.584794                 -0.61464        -0.001063 -0.276305
# 3         -1.584794                 -0.61464        -0.001063 -0.210785
# 4         -1.584794                 -0.61464        -0.001063 -0.144189
#
#    promo_used  avs_match  cvv_result  three_ds_flag  shipping_distance_km  \
# 0           0          1           1              1              0.032504
# 1           0          0           0              0             -0.485020
# 2           1          1           1              1             -0.451209
# 3           0          1           1              1              0.094350
# 4           0          1           1              1              1.352045
#
#    hour  ...  bin_country_NL  bin_country_PL  bin_country_RO  bin_country_TR  \
# 0     4  ...           False           False           False           False
# 1    20  ...           False           False           False           False
# 2     6  ...           False           False           False           False
# 3    17  ...           False           False           False           False
# 4     1  ...           False           False           False           False
#
#    bin_country_US  channel_web  merchant_category_fashion  \
# 0           False         True                      False
# 1           False         True                      False
# 2           False        False                      False
# 3           False         True                       True
# 4            True         True                      False
#
#    merchant_category_gaming  merchant_category_grocery  \
# 0                     False                      False
# 1                     False                      False
# 2                     False                      False
# 3                     False                      False
# 4                     False                      False
#
#    merchant_category_travel
# 0                      True
# 1                      True
# 2                      True
# 3                     False
# 4                     False
#
# [5 rows x 35 columns]
# is_fraud
# 0    0.977938
# 1    0.022062
# Name: proportion, dtype: float64

# %%
X
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 299690    0
# 299691    0
# 299692    0
# 299693    0
# 299694    0
# Name: is_fraud, Length: 299695, dtype: int64

# %%
# Save full processed dataframe
df.to_csv("processed_data.csv", index=False)

# Save features and target
X.to_csv("X_features.csv", index=False)
y.to_csv("y_target.csv", index=False)
